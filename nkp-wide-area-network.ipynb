# %%
from IPython.core.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from sys import path; path.insert(1,"../src");
import fubar; from importlib import reload; reload(fubar);
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-wide-area-network/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Wide Area Network``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %%
# from sys import path; path.insert(1,"../src")
# from fubar import fFile

# %%
# %%script bash
# grep -1 "def fFile" ../src/fubar.py -A 9
# Out:
# # repository ./SeanOhAileasa
# def fFile(nParPath):
#     """Start a file with its associated application.
#
# Input: nParPath
# Process: (os.path.realpath; os.startfile)
# Output: file opened with associated application
# """
#     from os import path,startfile
#     return startfile(path.realpath(nParPath))
# # --- END ---

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Wide Area Network](#topWideAreaNetwork)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topWideAreaNetworkTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topWideAreaNetwork"></a>
# ### [Wide Area Network](#wideAreaNetwork)
#
# - [1. Early Internet and WAN Service Types](#wideAreaNetwork1EarlyInternetandWANServiceTypes) <br/><br/>
# - [2. Current Internet and WAN Service Types](#wideAreaNetwork2CurrentInternetandWANServiceTypes) <br/><br/>
# - [3. Transmission Mediums](#wideAreaNetwork3TransmissionMediums) <br/><br/>
# - [4. Characteristics of Service - Switched](#wideAreaNetwork3TransmissionMediums4CharacteristicsofServiceSwitched) <br/><br/>
# - [5. Characteristics of Service - Point-to-Point](#wideAreaNetwork5CharacteristicsofServicePointtoPoint) <br/><br/>
# - [6. Termination](#wideAreaNetwork6Termination)

# %% [markdown]
# ### [Practice: Configure WAN Technologies](#practiceWideAreaNetworkConfigureWANTechnologies)
#
# * [1. Exercise: Configure WAN Technologies](#exerciseWideAreaNetworkConfigureWANTechnologies)

# %% [markdown]
# <a id="topWideAreaNetworkTest"></a>
# ### ⚡ [Test](#wideAreaNetworkTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork"></a>
# ***
# ### Wide Area Network
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork1EarlyInternetandWANServiceTypes"></a>
# ***
# ###### 1. Early Internet and WAN Service Types
# ***

# %% [markdown]
# In this presentation, we'll take a look at some of the methods by which you can establish Internet or WAN connectivity. Or perhaps more generally stated, just connections that can span large distances over provider subscribed networks.

# %% [markdown]
# Now, we'll begin with some of the early methods, but we'll also see some later ones in our next presentation. But that's not really to suggest that some of these early methods aren't still in use, some of them are. And some of them have progressed quite a ways. But they were just introduced much earlier than some of the ones that we'll see later.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dial-up - Public-Switched Telephone Network (PSTN)
# ***

# %% [markdown]
# So it really all began with dial-up. Historically, this was the main way to access the Internet from a small office or home office, or Small Office/Home Office (SOHO) environment. Or of course, from residential environments as well. So it used your public-switched telephone network to initiate a phone call to your Internet service provider. And that provided you with connectivity to the Internet. Now this had significant drawbacks, particularly by today's standards.

# %% [markdown]
# Modems, to this day, can only run up to 56 kilobits per second once they make an analog call per connection. Meaning that back in the old dial-up days, once you established this connection to get on the Internet, you could not make a phone call, your phone line was already in use. So unless you wanted a completely separate phone line dedicated to Internet access, you could not use the phone at the same time. And it was exceedingly slow by today's standards.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Integrated Services Digital Network (ISDN)
# ***

# %% [markdown]
# Now, this was superseded by ISDN, or Integrated Services Digital Network. And this was the first iteration, if you will, of high-speed Internet. It replaced dial-up Internet service, and it was still telephone based, but it uses a circuit switch or a dedicated line. In short, it means that your ISDN devices still use the public switched telephone network, but they could handle voice and data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### ISDN - Basic Rate Interface (BRI) ISDN
# ***

# %% [markdown]
# So they were, for starters, faster and they essentially use two dedicated 64 Kbps lines for a total of 128 kilobits per second. This was known as Basic Rate Interface, or BRI ISDN.

# %% [markdown]
# It was faster, and it could also handle your data and your voice at the same time. So in other words, you could use your Internet connection and make phone calls at the same time. So this was certainly a plus compared to dial-up.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### ISDN - Primary Rate Interface (PRI) ISDN
# ***

# %% [markdown]
# ISDN was also released as Primary Rate Interface, or PRI ISDN, and this version aggregated 23x64 Kbps channels together for voice or data use.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T Carriers
# ***

# %% [markdown]
# Now these digital carriers were destined to have a new format, however. As we saw the advent of the T carriers, T1 and T3 especially.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T1
# ***

# %% [markdown]
# Now T1 was the earlier, and it actually was the same wiring as PRI ISDN but with a different protocol running on top.

# %% [markdown]
# It was used for both home and commercial use, but it was generally used more so in the larger business environment. But somebody who worked from home or had a business in their home might have invested in a T1. And it was also able to accommodate both voice and data transmissions, so you did not have to sacrifice your phone for the Internet connection.

# %% [markdown]
# This was comprised of a series of digital channels, 24 in fact, that allowed for much faster speeds than standard Internet connections at the same time, approximately 1.5 megabits per second.

# %% [markdown]
# So again, significantly higher than ISDN.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### T3
# ***

# %% [markdown]
# And then T3 came along, which was also known as Digital Signal 3 or DS3. And its transmission rates, again, were far higher than T1.

# %% [markdown]
# Ideal for large corporate networks, as they could accommodate much larger amounts of traffic. It was absolutely not designed for home or small office networks. They were significantly more expensive, they were up around 35, 36 megabits per second in terms of their speed, but they could costs thousands per month. So generally, you did not see T3 connections in a small office or home environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### E1 and E3
# ***

# %% [markdown]
# Now E1 and E3 are fairly similar to T1 and T3. They're still WAN digital communications mediums, and as you can see, slightly different rates in terms of the megabit per second value. E1 around 2, and E3 around 34 megabits per second.

# %% [markdown]
# And they had basic time-division multiplexing schemes for digital circuits. Effectively, they were implemented more frequently outside of North America. And sometimes, you would even hear people referring to the E as European because it was very commonly used there. But I don't believe it actually stood for that.

# %% [markdown]
# But an E3 can carry up to 16 E1 circuits. So again, it was just a more robust implementation of the same type of methods used to establish the connections.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Optical Carrier (OC)
# ***

# %% [markdown]
# Finally, we have the OC standard, such as OC-3, which stands for Optical Carrier, and then the level indicated by the number.

# %% [markdown]
# And we focus O3 because it was simply a very common implementation of Optical Carrier standards. But you can see, there's a number of levels, and the rate goes up accordingly with your level to very high rates by the time you get to OC-192.

# %% [markdown]
# So this implemented standardized protocols which are used for transferring data over fiber optic networks. So it depended on the specifications in terms of the overall rate. But you can see, the level incrementing in a bit of a strange fashion.

# %% [markdown]
# The OC level is really just a value that indicates your level. And you have an according STS value, or an electrical level, that actually stands for Synchronous Transport Signal. But in simpler terms, it indicates the basic unit of transmission.

# %% [markdown]
# So with an STS-1, the basic unit of transmission of 1, your rate was 51.84 megabits per second.

# %% [markdown]
# An STS-3 is three times higher. And you can see that the line rate triples accordingly. STS-9, now we have nine times the original. It's nine times faster, triple the previous one.

# %% [markdown]
# Now, it didn't triple each time. You can see the next one is 12, then 18, then 24. But that number after the OC and/or the STS simply meant a multiplier of 51.8. So if you did the math for, let's say, STS-36, it would be 36 times 51.84, the basic level, the STS-1.

# %% [markdown]
# So they got up fairly high by the time you get to STS-192.

# %% [markdown]
# Now the STM is a framing unit, and this was defined by SDH, which is the Synchronous Digital Hierarchy. So they define these Synchronous Transport Modules, and each module could contain three basic units of transmission. So you can see that the STM-1 had three STS-1 units in it. So the value of the STM is always one-third of the STS.  So again, it was just a method of framing and putting those basic units of transmission together.

# %% [markdown]
# Not unlike a packet, if you will. But the correct term in this case is framing. But again, the higher you go, the faster your connection.

# %% [markdown]
# And, ultimately, by today's standards we're seeing the speeds that are typically used for connecting the backbone of the Internet, the largest network in the world, OC-192 with data speeds upwards of ten gigabits per second. But that certainly is not something that you would see in smaller offices or maybe even medium sized. These would be the largest, most robust connections on the go today. But again, this is a method started quite some time ago, in fact, as far back as the early 1980s. So it simply just evolved into a very robust method of WAN connectivity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork2CurrentInternetandWANServiceTypes"></a>
# ***
# ###### 2. Current Internet and WAN Service Types
# ***

# %% [markdown]
# Now in this presentation we'll take a look at some of the more current options available for implementing high speed Internet and/or WAN connectivity, beginning with DSL or digital subscriber line.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Digital Subscriber Line (DSL)
# ***

# %% [markdown]
# Now this was typically offered by the phone companies because it came in over your phone service. So you would connect your DSL modem to your phone jack with a standard telephone cord. Then connect your computer to the DSL modem using a standard Ethernet cable. And optionally, if you needed to set up a small network or just share the connection you could implement a router, but that was up to you.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Digital Subscriber Line (DSL) - Bandwidth
# ***

# %% [markdown]
# Now DSL has some variants, and we'll see some examples in a moment. But they dealt with the fact that DSL is divided with respect to the bandwidth.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Asymmetric DSL (ADSL)
# ***

# %% [markdown]
# Now most home broadband connections are typically implemented as ADSL connections which means asymmetric DSL.

# %% [markdown]
# And it takes the overall bandwidth and divides it up between download speeds and upload speeds. And the standard ADSL connection heavily favored download speeds. It offered up to 24 megabits per second, which was pretty good at that time. But in terms of just regular browsing, regular downloading of multimedia content, this is exactly what people wanted. They wanted most of the bandwidth dedicated to downloading because they almost never uploaded anything.

# %% [markdown]
# So I believe the standard division was about 85 to 15 in terms of percentages. So 85% dedicated to downloading, only 15 to uploading.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Symmetric DSL (SDSL)
# ***

# %% [markdown]
# But that didn't always work. In some cases you needed symmetric DSL. [Symmetric DSL is also known as Symmetric Digital Subscriber Line, or SDSL for short. ] And this immediately appeared to be slower on the download side and in fact it was. But it wasn't that there was less bandwidth available overall. It was just the division. So where ADSL was about 85 15, SDSL is 50 50. Download and upload speeds are equal. So why would you want this seemingly slower connection? Well, if you were using the connection for business purposes then there were a few different applications that required it. Most notably, voice over IP, and/or video conferencing. Those real time communications need an equal upload and download speed. You might have also just been uploading a lot of content to maybe your corporate headquarters over a VPN. So if you were just doing a lot of uploading as well, then you needed a more balanced connection.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Very-high-bitrate DSL (VDSL)
# ***

# %% [markdown]
# Now the VDSL is very-high-bitrate DSL and it is quite simply faster, capable of supporting connections of up to 100 megabits per second, which was much faster at that time. But as you can imagine it was also more expensive.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Metropolitan Ethernet -  Metropolitan Area Network (MAN)
# ***

# %% [markdown]
# Now the metropolitan Ethernet is effectively just a MAN, a metropolitan area network.

# %% [markdown]
# But rather than using WAN type of connections it used regular Ethernet. [MAN is based on Ethernet layer 2 protocol. ]

# %% [markdown]
# So this was far cheaper than some of the earlier options, which were SONET, which for all intents and purposes is fiber, that is synchronous optical network. And SDH was the hierarchy, the synchronous digital hierarchy, that was actually referenced in the previous presentation, but it was effectively fiber. So it was far cheaper due to the ubiquity of Ethernet.

# %% [markdown]
# Everybody had Ethernet. And you could simply interface your branch offices with your data center and your head office by using your existing infrastructure. So it was effectively implementing a MAN but using regular standard Ethernet. So this was still something that you had to subscribe to. You had to have a provider to handle the connections but it was a lot cheaper than using fiber. [So, MAN networks interface easily with customer networks.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Cable Broadband
# ***

# %% [markdown]
# And finally, cable broadband. This was a high-speed Internet option that came in over the same service as your cable TV, typically coaxial cable.

# %% [markdown]
# So where your phone company tended to provide DSL, your TV company, if they were different, tended to provide cable broadband. It offered bandwidth of up to 400 megabits per second, although that did vary depending on the country and some of the connection standards. Now, those standards were specified in a document known as Data Over Cable Service Interface Specification or DOCSIS.

# %% [markdown]
# But again it was generally something that was available anywhere that you had connectivity to a cable TV provider and certainly offered very high speeds for home Internet in particular. So the type of connection that you might have implemented depended on things like proximity to which provider. Were you closer to the phone provider, closer to the cable provider, because there were still distance considerations. Of course the cost and the speed. And in essence just what you felt was going to work best for you when it came to the speed versus the price. But those are still very commonly used in today's environments, and particularly when just needing to set up a standard high speed Internet connection.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork3TransmissionMediums"></a>
# ***
# ###### 3. Transmission Mediums
# ***

# %% [markdown]
# Now in this presentation, we'll take a look at some of the physical media types used for establishing WAN and or high speed Internet connectivity, beginning with satellite.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Satellite
# ***

# %% [markdown]
# And this of course is often used where no other technologies are available. [Satellite can be used for WAN/Internet connectivity.] Particularly when you are very remote, such as a ship or an oil rig out in the middle of the ocean, or just a very remote location on land. Then satellite can be ideal, but satellites, of course, are not particularly close.

# %% [markdown]
# So based on the distance involved, delays can certainly be an issue. Now, that does depend on what you are using the connection for. For example, if you are just looking to download data, then that might not be a big deal, but real time communications certainly would become an issue. There would be noticable delays in communication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Advantages
# ***

# %% [markdown]
# But in terms of the advantages, it is available anywhere, quite literally anywhere on the globe can be accessed by satellites. So it's, again, very good for these isolated areas that lack any other kind of infrastructure, but it of course has its disadvantages as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Disadvantages
# ***

# %% [markdown]
# It's fairly expensive. Satellite service is not cheap and it's not particularly fast and it can also be impacted by weather. So again, it's certainly suitable when you just have no other option, but does have some downsides.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Copper
# ***

# %% [markdown]
# Now, copper is the one that's used most often for cable Internet. And it has the advantages of being inexpensive, and easy to implement ,and very expandable, meaning that, of course, if you already have cable TV in your house, any cable outlet can be used to provide the service.

# %% [markdown]
# But it does also have some disadvantages. There is a distance limitation when using the copper cable itself. Typically, customers needed to be within 3.6 kilometers of the provider. In fact, the original cable specification that was implemented when cable Internet was introduced was known as ten broad 36. And that again stood for ten megabytes per second, but broadband transmission instead of baseband, which used the electrical variance to carry the data of cable TV. Now, the Internet was digital, but the cable itself was originally designed for cable TV, which did use broadband transmissions. And the 36 meant 3,600 meters, or 3.6 kilometers. So if you did not fall within that range of a transmission center, or even any kind of relay station, then you were quite simply ineligible to receive the service.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Copper Cable
# ***

# %% [markdown]
# Now in terms of the cable itself, I just wanted to mention that it was not the same coaxial cable that was used in the early Ethernet implementations.

# %% [markdown]
# For that we see there was a 50-Ohm, that's the resistance of the cable, RG7 or RG11, which was commonly known as thick Ethernet or Thicknet. And then a 50-Ohm RG58 cable which was quite literally a little thinner and this was known as Thin net. But again, those were the LAN implementations of coaxial cable, they were not used for high speed cable Internet.

# %% [markdown]
# That was the last cable you see there, the 75-Ohm RG-59. And this was the one that was used originally with cable TV and, of course, cable Internet. So it was certainly very easy to implement because a lot of people already had this cable running into their homes. So as long as you had that, then you could subscribe to the high speed Internet. So it caught on quite well, quite quickly, but is been superseded, these days in a lot of cases, by fiber.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Fiber
# ***

# %% [markdown]
# So, fiber optic cabling is often used in network backbones, and provides high bandwidth communication. It's fast and reliable, and very commonly implemented now for home Internet as well.

# %% [markdown]
# So in terms of the advantages, fiber certainly offers greater speed. It has better resistance to electromagnetic interference, [Electromagnetic interference is referred to as EMI.] it can cover much greater distances, and also offers enhanced security. It's actually quite difficult to tap fiber optic cable, but it does still have some disadvantages as well.

# %% [markdown]
# The costs involved are a little higher for the cabling, the connectors and the appliances, but that's really more so from the perspective of LAN implementations as opposed to home Internet service.

# %% [markdown]
# And the installations can still be a little more difficult compared to common Ethernet implementations. But again, when it comes to home service, you still basically have to do the same thing. You have to call your provider, they send someone to come and install it, and once it's all set up, then really there's not much to deal with.

# %% [markdown]
# So by comparison, it's not really any different than let's say the DSL or the cable modem service. You have similar equipment, it's just that different physical media, but the costs are comparable these days, and of course, the performance is much better over fiber. So this is rapidly taking over from the other high speed Internet options and even, of course, in WAN implementations.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork3TransmissionMediums4CharacteristicsofServiceSwitched"></a>
# ***
# ###### 4. Characteristics of Service - Switched
# ***

# %% [markdown]
# Now in this presentation, we'll take a look at some characteristics of WAN connectivity. And begin by separating out circuit-switched and packet-switched networking.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Circuit-switched Network
# ***

# %% [markdown]
# A circuit-switched network, allows a node to connect to the switching service and request a connection to another endpoint.

# %% [markdown]
# Once connected through the switching media to that endpoint, those links and switching resources are devoted to maintaining that connection and no other. Once a circuit is made, no further pointers are necessary.

# %% [markdown]
# The telephone network is a circuit switch network, which is why you don't have to keep reentering the phone number every time you want to say something. The circuit is already established. And why, if more people call an area. For example, after a natural disaster, than there are circuits available, the caller might get notified that all circuits are busy which means that all the possible links are already in use. [Circuit-switched networks are PTSN and ISDN. The connection dedicates point-to-point use of resources. ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Packet-switched Network
# ***

# %% [markdown]
# The next type of network is a packet-switched network. In this situation, the establishment of the connection of a node to a switch indicates the potential to reach a destination, but the destination is still unknown.

# %% [markdown]
# This is more like coming to an airport, where you won't really go anywhere until you present your ticket at the gate, and then you can get on a plane to go somewhere.

# %% [markdown]
# With a packet-switched network, each packet must have the address of the intended destination written on it. So that the switch can examine it, and forward it to a destination. If that sounds familiar, it's because it's exactly how ethernet switched network works. [Packet-switched networks are Ethernet, ATM, frame relay, and MPLS. Each frame is checked and forwarded using addresses. ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Type - Frame Relay
# ***

# %% [markdown]
# Now, the first specific network type we'll look at is Frame Relay.

# %% [markdown]
# Which is a layer 2 WAN technology that implements packet-switching telecommunication.

# %% [markdown]
# Now, before going forward we call that packet-switching in of itself it's based on two endpoints that need to communicate with each other. But before they can do so, they have to establish a connection. But they only need the connection for the duration of the communication. Then, it shuts down.

# %% [markdown]
# Again, very common day-to-day example, a phone call. The physical phone network is always there. But in order for me to use it, I have to pick up the phone, dial the right number, the person must pick up the other end, then we can communicate. When we're done, we hang up. And of course, while we aren't using it, then the infrastructure and the bandwidth is there available for other people to use. So we'll all share it, of course. So this is still packet-switching very much like a LAN environment. But it's over WAN communication methods. So in a lot of cases, it's like a public switch telephone network.

# %% [markdown]
# So we can't just do ethernet switching over things like a phone network. But this was a cost effective solution because of the fact that the data transmission only occurs on that intermittent basis between the WAN endpoints again as needed. Just like when I hang up the phone and I'm done with my conversation, it is available for other people to use. So that's as needed basis.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Addressing - Frame Relay - Data Link Connection Identifier (DLCI)
# ***

# %% [markdown]
# Now in terms of addressing, again, this is another reason why you can't just implement LAN communications. It uses a method known as DLCI or data link connection Identifier.

# %% [markdown]
# And again, for very general day to day analogies, this would be the phone number. This addresses the other endpoint. So once you've located the other endpoint, the two sides are connected within a network of virtual circuits. Virtual circuits are also known as VCs.

# %% [markdown]
# And again, the virtual circuit means the physical media is always there, but I'm not using it all the time, I only use it when I need it. So it's very much like a phone call, but of course, we're exchanging data between computers. So it's something that was quite popular when it was first released, but is being certainly discontinued, because it's very slow by current standards. It only offered speed of up to 1.544 megabits per second. So again, very slow by today's standards, but back when it was first released that was pretty good.

# %% [markdown]
# And again, it was based on the fact that we only need that bandwidth for a little while, then we shut down and other people can use it. Because again, even with your home phone system you aren't using it most of the time. So you could take advantage of the fact that most people weren't using it most of the time, so you could get better bandwidth than, of course, the dial up. But again, by today standards, it's fairly slow.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Type - Asynchronous Transfer Mode (ATM)
# ***

# %% [markdown]
# So ATM is another option. ATM stands for Asynchronous Transfer Mode.

# %% [markdown]
# And this is also a layer 2 WAN technology that uses a virtual path identifier, virtual circuit identifier or VPI, VCI for addressing. So again, it was still based on the fact that, you have to identify the endpoint and you still have to make a connection to that endpoint. It use different methods of transmitting. Now this is actually older than frame relay, but is still used to a certain degree in high end ISPs. Because it was actually much faster than frame relay, despite the fact that it's actually older.

# %% [markdown]
# You could typically find bandwidths of 155 megabits per second, to 622. So significantly faster than frame relay. And the basic idea behind ATM was to not just be a data switching technology but rather all types of information. Data, voice and video so that we could consolidate all these types of transmissions into a single protocol, and it provided guaranteed bandwidth by using a fixed cell size. This is the reason why they call it a cell. Because a packet is officially variable in size.

# %% [markdown]
# With ATM, it was a very small cell size of only 53 bytes. So it used that in combination with time division multiplexing, which is referred to as TDM for short. You can see the multiplexer in the graphic. It's used to establish virtual circuits and begin transmitting data. But that fixed cell size reduced a lot of overhead. Basically, it didn't care what kind of data it was. Whether or not it was voice or video or traditional data, it just packed 53 bytes into every cell and sent it on its way. So it was very efficient, hence some of the greater speeds. But it also required dedicated equipment that could be fairly costly. And while still being implemented by some ISPs, never really caught on in private corporations because of the costs involved and the complexity of the implementation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Type - Multiprotocol Label Switching (MPLS)
# ***

# %% [markdown]
# Finally, MPLS or Multiprotocol Label Switching.

# %% [markdown]
# Is a method to enable efficient routing based on labels, hence the L of the MPLS.

# %% [markdown]
# Now, what you see here is the interior of the cloud is what's called the label switch router.

# %% [markdown]
# And that's just a router enabled for this protocol.

# %% [markdown]
# Then the ELSR is the Edge Label Switch Router. And then the CPE stands for Customer Premises Equipment, so those would be our routers. [The graphic shows a router process between Site A and Site B using the Service provider's MPLS cloud. From Site A, the CPE connects to the ELSR, which is connected to the LSR. This in turn is connected to another ELSR, this connects to a CPE and on to Site B. The routing path is multi-directional.]

# %% [markdown]
# The ELSRs would be the Internet Service Provider to which you're connected. The LSRs just represent the internet.

# %% [markdown]
# But the idea behind the routing methodology here is to simply attach a label to the packets that indicate a known virtual path to this router. Traditional routers have to examine the packet, locate the network address, look that up in its routing table, and then forward that to the next router based on that information. And the next router has to do the same thing, and it just carries it on as it goes from router to router to router.

# %% [markdown]
# In this case, it just reads the label, which, if you will, is the first thing it sees. And it sees a path to a distant router, it just says, here you go. You know, go about your business, go on to your way to that distance router and keep doing that until you arrive at the endpoint. But this enabled you to arrive at the endpoint when it came to routing and overall, just much simpler implementations.

# %% [markdown]
# And because of the fact that it only looked at the label and then nothing else, you can actually route traffic from different protocols. Because it quite literally did not care. It saw the label and said, off you go. So it was actually able to incorporate different types of traffic. Such as frame relay, ATM, DSL, T1, it didn't care. Whatever it was, any type of protocol could be implemented and could be pass through in LSR type of router. So this is a bit of a newer kit on the block if you will. But not overly new by today's standards. It was early released in the late 90s. But it's still being adopted because of the some of the older methods still being in place. But I think you'll start to see more MPLS coming into the picture as things move forward. And ultimately, these are all just different methods for moving traffic around in terms of WAN interconnectivity. And if you're talking about creating these types of connections between your own sites, within your own organization, then you certainly might consider some of these. But things like VPNs are certainly still an option as well. And our point-to-point connections which we'll actually look at in our upcoming presentation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork5CharacteristicsofServicePointtoPoint"></a>
# ***
# ###### 5. Characteristics of Service - Point-to-Point
# ***

# %% [markdown]
# Now in this presentation, we'll take a look at some additional characteristics of WAN connections, but this time using point-to-point connections. And we'll begin with what is essentially the foundation of a lot of these types of connections, the Point-to-Point Protocol, or PPP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Point-to-Point Protocol (PPP)
# ***

# %% [markdown]
# Now, to again use an analogy, if we consider the phone network, a plain old phone call is in fact a point-to-point connection.

# %% [markdown]
# I have to pick up the phone, I have to dial the number. The other person has to answer the phone. That establishes the connection and then we can talk. That is point to point.

# %% [markdown]
# But with respect to connections that use point-to-point communications in networking, it is more so used to establish a permanent virtual connection as opposed to a switched virtual connection.

# %% [markdown]
# And again, you can still kind of imagine the same thing with a phone call. I can call you on the phone, and as long as we're communicating, we need that connection available to us. But then when we are done, we typically hang up. But, in fact, we don't have to hang up, we could leave both phones off the hook. And if we feel like we are going to communicate again in a few minutes, or even hours later we would just have to pick up the phone and the connection would still be there. So that's typically where you see point-to-point connections implemented in network environments, when you need something that is a little more permanent. Maybe we aren't transferring data all the time, all day long, but it is fairly regular. So much so that it makes a little more sense to just leave it connected, than it does to open it, send, close, open, send, close, open, send, close.

# %% [markdown]
# So, again, we see a little bit more of a permanent connection even though it is still officially a switched connection that we do still close once we're done. But, again, that sort of the general idea of point-to-point connections.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Point-to-Point Protocol (PPP) - Uses Link Control Protoco (LCP)
# ***

# %% [markdown]
# Now it also uses what's known as the Link Control Protocol, or LCP, to transport upper layer protocols so that we can, in fact, extend its capability. Protocols that go higher up in the stack can be used to pass information over this connection.

# %% [markdown]
# So, again, coming back to the phone call analogy, we normally just speak over that connection. But let's go back 10 or 15 years, before the advent of things like FaceTime and Skype and video conferencing. Imagine back then if we could all of a sudden just send different data over that phone call, send a fax, send a picture, send video communications. You know we weren't really able to do that back then, but that's the idea of introducing higher layer protocols. We can use them for different types of communication over the same connection.

# %% [markdown]
# So LCP, which again, gives us access to the higher layers, also provides features such as loop detection, error correction, authentication, and aggregation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Link Control Protoco (LCP) - Loop Detection
# ***

# %% [markdown]
# Now loop detection is the fact that as packets route themselves around on the Internet, many routers can consider a bunch of different factors as to how they will send that data to the next router. So it is, in fact, possible that because of those differences in possible paths, it might actually find its way back to you, that's loop detection. So it prevents that from happening, basically it detects it and stops it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Link Control Protoco (LCP) - Error Detection
# ***

# %% [markdown]
# Error detection is exactly as its name indicates. If something is detected to be missing in terms of the communication, it will just re-send the information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Link Control Protoco (LCP) - Authentication
# ***

# %% [markdown]
# And, of course, do consider the fact that we are using the Internet as the communication medium now, not the phone line. So as such, we need a way to make this very public network private. So we can implement authentication and, in fact, features such as encryption, so that the communications are secure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Link Control Protoco (LCP) - Aggregation
# ***

# %% [markdown]
# And aggregation is the ability to create multiple links over the connection, so we can increase the overall bandwidth. [LCP provides aggregation using a virtual multilink interface.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Point-to-Point Protocol over Ethernet (PPPoE)
# ***

# %% [markdown]
# So then, the Point-to-Point Protocol, as mentioned, can act as the foundation for different types of connections including Point-to-Point Protocol over Ethernet, or PPPoE.

# %% [markdown]
# And this is a specification that's used to connect multiple users on an Ethernet LAN to a remote site, which in most cases is just the Internet.

# %% [markdown]
# But it uses customer premises equipment. Now that equipment is typically supplied by the Internet service provider, but it stays on your premises. You then use it to simply share the connection.

# %% [markdown]
# So, typically, what you would do in terms of gaining access to the Internet for a business environment is that you would just get one subscription. You would call up your Internet service provider and say, send some Internet to this location. But you only needed that one connection, but you needed to then share it amongst multiple users. So a set of credentials was set up to establish connectivity back to the Internet service provider. But you didn't need separate credentials for every single user within the Ethernet LAN environment. All of you accessed the single connection through the PPPoE server. So it effectively shared the connection and allowed us all to use that Internet connection.

# %% [markdown]
# And, in essence, this is what you saw with DSL and cable modems. We could implement a way for all of us to use that connection, as opposed to just a single computer using it at any one given time. [In essence, PPPoE is used in office environments to share a common connection to the Internet.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dynamic Multipoint Virtual Private Network (DMVPN)
# ***

# %% [markdown]
# Now a DMVPN is a dynamic multipoint virtual private network, and this is still a VPN, which is a secure network for exchanging data between parties.

# %% [markdown]
# But a traditional VPN requires that I make my connection into something, like, let's call it corporate headquarters, through a single VPN server. Then it might be able to connect me through to various resources within the environment. [A DMVPN does not require traffic to pass through a main VPN or router.]

# %% [markdown]
# But in situations where you have multiple branches, rather than Branch 1 needing to communicate with Branch 2 through headquarters, it only contacts headquarters long enough to find out what is the connection information. And once that is known, then a direct connection is established between Branch 1 and Branch 2. So we only contact the hub for the correct information. Where do I go to get to Branch 2, Branch 3, Branch 4 and so on? Once I receive that, I establish these direct connections dynamically and traffic does not pass through the hub in headquarters. So it's a little more efficient. [A diagram displays. It illustrates three branches, each connected separately to a hub, via spokes.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Session Initiation Protocol (SIP) - SIP Trunk
# ***

# %% [markdown]
# And finally, an SIP trunk is a Session Initiation Protocol method of trunking which allows business phone systems to operate using an Internet connection as opposed to a traditional phone line.

# %% [markdown]
# So it's a regular phone system that you have within your office environment that can then go through an SIP trunk and, in fact, use Voice over IP across the Internet to get to other locations.

# %% [markdown]
# So I have a plain phone system, not a Voice over IP system, but I can then use it across the public telephone network in a Voice over IP fashion. So this costs less, it's very scalable, and it's very reliable in terms of establishing these connections. So it is still something that you have to subscribe to, it's a service that you pay for. But it essentially changes up the signals, if you will, from the standard analog electrical signals between you and the SIP trunking point and then the other ends, and in between it uses Voice over IP.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - WAN Interconnectivity Methods
# ***

# %% [markdown]
# So, again, these are all just WAN interconnectivity methods.

# %% [markdown]
# But they all involve these point-to-point options with respect to connectivity, as opposed to some of the packet switching options that we saw earlier, including Frame Relay, ATM, and Multiprotocol Label Switching.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetwork6Termination"></a>
# ***
# ###### 6. Termination
# ***

# %% [markdown]
# In this presentation, we'll take a look at some considerations for terminating network communications. And this becomes important particularly in troubleshooting because it marks a boundary, with respect to responsibility. In other words who is responsible for correcting in a given problem?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Demarcation Point (demarc)
# ***

# %% [markdown]
# So the first consideration is what's known as a demarcation point. [The Demarcation point is also called the demarc.]

# %% [markdown]
# Now this does not necessarily refer to any specific type of device or hardware, but rather just the physical point where a public network and a private network interconnect. So the telecommunications network would be the provider and your business would be the organization. So this is quite literally where the two meet.

# %% [markdown]
# Now, the demarcation point is generally installed on site at the local business. It's typically a grey box that might be installed on the outside of the business. So their cabling runs into the box from your perspective and then your cabling runs out of the box into the building.

# %% [markdown]
# Now, if it's a home or residential service then the demarcation point is typically installed inside maybe in the basement or in an attic or just somewhere out of the way usually but again, that physical point marks the boundary.

# %% [markdown]
# So if a problem occurs, then determining who is responsible for that problem is quite literally, well which side of the demarcation point is encountering the problem. So to use very simple examples, if I trip over a cable and yank it out of the router and the cable breaks. Well clearly, that's my problem.

# %% [markdown]
# But if something happens on the outside. Let's say a branch of a tree falls down and rips a cable out of the demarcation point on the outside, then that is actually their problem.

# %% [markdown]
# So it really does mark that physical boundary so when problems occur you may call lap the provider for assistance. They can usually test to see whether or not the signal is making it to demarcation point. And, if it is then more or less they can say, well, it's not really our problem, there's something wrong on the inside. Now they might be able to assist you but they might also charge for that service. But as mentioned if they can not get signal back from the demarcation point, then they can say well yes, it looks like there's a problem with our service and accordingly they will have to look after that. [A diagram displays. It illustrates a Core Switch connecting to the Distribution Switch, which then connects to the Edge Switch, which is on the side of the private network. The DMARC is represented as a barrier between the public network and the private network.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Type of Demarcation Point (demarc) - Channel Service Unit / Data Service Unit (CSU/DSU)
# ***

# %% [markdown]
# Now a CSU, DSU, is a channel service unit, data service unit, and a type of demarcation point.

# %% [markdown]
# But this is a specific hardware device that is used to convert digital data frames on a LAN Into the appropriate frames for a WAN.

# %% [markdown]
# And these were typically implemented for the T carriers, the T1 and the T3, but again it was a type of demarcation point. This did mark the boundary between your network and the provider's network.

# %% [markdown]
# So the CSU connects a terminal to a digital line. It really is quite literally the connection and the DSU carries out functions for a telecommunication line such as protection and diagnostics.

# %% [markdown]
# Now they typically were a single device you saw a both functions within the single device, but one more so for diagnostics and communications protection, and the other for quite literally the physical connection itself. [A diagram illustrates the Channel Service concept. Two networks are displayed. In each network, two computers are connected to a router, which is in turn connected to a CSU/DSU via a serial. A WAN connects the two networks via the CSU/DSUs units.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Demarcation Point for Service Responsibility - Smart Jack - Network Interface Unit (NIU)
# ***

# %% [markdown]
# Then you also might hear the term smart jack, which is also referred to as a network interface unit. [Network Interface Unit is NIU, for short.]

# %% [markdown]
# Which quite simply, is used as the common interface for other devices in a local area network, to enable communication between the devices, using a variety of protocols.

# %% [markdown]
# But in most implementations, a smart jack referred to loop back capabilities of a device, such as a CSU DSU or any other demarcation point. It helps isolate any problems, using what's known as intrusive bit error rate testing.

# %% [markdown]
# Quite simply, the ability to test for connectivity.

# %% [markdown]
# So you can perform these types of monitoring functions so that the service provider can say well I am getting a signal right up to the demarcation point. I'm getting responses. These loop back capabilities. So, that's when the service provider can say, the problem does not appear to be on our end, so it's this diagnostic capability of the interface itself to report back if you will and say everything looks good from the provider's end right up to the demarcation point.

# %% [markdown]
# So, they basically convince, suggest to you, try this, try this, check the cables, check the devices, but it does not seem to be a problem on our end because I am getting this loopback information from the device. So again, it's all about trying to determine where the problem resides and who is responsible for correcting that problem. [In other words, an NIU is often a demarcation point for service responsibility.]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practiceWideAreaNetworkConfigureWANTechnologies"></a>
# ***
# ### Practice: Configure WAN Technologies
# ***

# %% [markdown]
# i. List the various WAN/Internet service types.
#
# ii. Then to describe the various transmission mediums.
#
# iii. Then to describe the benefits of Multiprotocol Label Switching. [MPLS, for short.]
#
# i.v And finally, to describe the benefits of Point-to-Point Protocol over Ethernet. [Point-to-Point Protocol over Ethernet is sometimes refered to as PPPoE.]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exerciseWideAreaNetworkConfigureWANTechnologies"></a>
# ***
# ###### 1. Exercise: Configure WAN Technologies
# ***

# %% [markdown]
# i. All right, so to review, we asked to first list the various WAN/Internet service types.

# %% [markdown]
# And there are several, but they include dial-up, ISDN, T1 or T3, E1 or E3, OC-x, where x indicates the level. Typically 3 was common in early implementations, up as high as 192 for some of the later. DSL, cable, and Metropolitan Ethernet. And each one had various benefits and drawbacks.

# %% [markdown]
# ii. Then we asked to describe the various transmission mediums. And they include satellite, copper, typically coaxial, and fiber.

# %% [markdown]
# And satellite, of course, had the advantage of being available globally. You could reach just about anywhere. But fairly expensive, not particularly fast.

# %% [markdown]
# And the reason why coaxial was specified for copper is because, again, the distances that were necessary to handle high speed Internet, for example, could not be accommodated in most cases by some of the twisted pair cables such as Cat 5. Ethernet implementations are still limited to 100 meters. But the copper cable that was used, for example, for cable TV and cable Internet could actually travel 3.6 kilometers.

# %% [markdown]
# Fiber much further and even faster in terms of the transmission rates. But was initially fairly expensive, but has certainly come down a lot in price so it's becoming very common in today's environments.

# %% [markdown]
# iii. Then we asked to describe the benefits of MPLS, or Multiprotocol Label Switching.

# %% [markdown]
# This offers very efficient routing due to the fact that the routers only examine the label. They do not need to look up all of the network addresses in their routing tables.

# %% [markdown]
# And it offers support for multiple protocols. So it really just doesn't care what protocol is being used. So it's very efficient and very practical.

# %% [markdown]
# iv. And finally, we asked to describe the benefits of Point-to-Point Protocol over Ethernet.

# %% [markdown]
# And the primary benefit here is the ability to share a single Internet connection among multiple users. So as opposed to just one person having access to the connection, an entire office, for example, can all use that same connection at the same time, with just using a single set of credentials to authenticate the connection, but able to then be used by everyone.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wideAreaNetworkTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# # END JUPYTER NOTEBOOK
